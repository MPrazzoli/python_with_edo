# %%
import investpy

# %%
investpy.indices.get_index_countries()
# Out:
# ['argentina',
#  'australia',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belgium',
#  'bosnia',
#  'botswana',
#  'brazil',
#  'bulgaria',
#  'canada',
#  'chile',
#  'china',
#  'colombia',
#  'costa rica',
#  'ivory coast',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'ecuador',
#  'egypt',
#  'estonia',
#  'finland',
#  'france',
#  'germany',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'latvia',
#  'lebanon',
#  'lithuania',
#  'luxembourg',
#  'malawi',
#  'malaysia',
#  'malta',
#  'mauritius',
#  'mexico',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'namibia',
#  'netherlands',
#  'new zealand',
#  'nigeria',
#  'norway',
#  'oman',
#  'pakistan',
#  'palestinian territory',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'qatar',
#  'romania',
#  'russia',
# ...

# %%
usa_indices_df = investpy.indices.get_indices(country='united states')
usa_indices_df
# Out:
#             country                                        name  \
# 0     united states                         NQ US Mid Cap Value
# 1     united states                        NQ US Mid Cap Growth
# 2     united states  NQ US Mid Cap Telecommunications Equipment
# 3     united states                NQ US Mid Cap Semiconductors
# 4     united states             NQ US Mid Cap Computer Hardware
# ...             ...                                         ...
# 1373  united states                                 DJ Internet
# 1374  united states                     DJ Integrated Oil & Gas
# 1375  united states                        DJ Insurance Brokers
# 1376  united states           NQ OMX Green Economy ex-US TR USD
# 1377  united states               DJ Global ex-U.S. Select REIT
#
#                                            full_name     symbol currency  \
# 0                            NASDAQ US Mid Cap Value     NQUSMV      USD
# ...

# %%
usa_indices_df['class'].value_counts()
# Out:
# other_indices         1285
# primary_sectors         64
# additional_indices      13
# bonds                   10
# major_indices            6
# Name: class, dtype: int64

# %%
usa_indices_df.iloc[740:800]
# Out:
#            country                                           name  \
# 740  united states                      NYSE Arca Gold Miners GTR
# 741  united states                NYSE Market Composite Financial
# 742  united states               NYSE Market Composite Healthcare
# 743  united states                              S&P 400 Utilities
# 744  united states                                NYSE Tick Index
# 745  united states                 S&P 600 Consumer Discretionary
# 746  united states                                 S&P 600 Energy
# 747  united states                          S&P Computer Hardware
# 748  united states                      S&P Health Care Equipment
# 749  united states                       S&P Health Care Services
# 750  united states                               S&P Homebuilders
# 751  united states                      S&P Industrials Composite
# 752  united states                            S&P Metals & Mining
# ...

# %%
usa_indices_df[usa_indices_df['full_name'].str.contains("Green")]
# Out:
#             country                                name  \
# 1191  united states             NQ OMX Green Economy US
# 1326  united states    NQ OMX Green Economy Asia TR USD
# 1327  united states                NQ OMX Green Economy
# 1329  united states            NQ OMX Green Building TR
# 1337  united states          NQ Clean Edge Green Energy
# 1343  united states               NQ OMX Green Building
# 1348  united states      NQ OMX Green Transportation TR
# 1354  united states         NQ OMX Green Transportation
# 1355  united states                  NQ OMX Green IT TR
# 1357  united states                     NQ OMX Green IT
# 1359  united states             NQ OMX Green Economy TR
# 1362  united states      NQ OMX Green Economy ex-US USD
# 1363  united states     NQ OMX Green Economy Europe USD
# 1364  united states  NQ OMX Green Economy Europe TR USD
# 1365  united states       NQ OMX Green Economy Asia USD
# 1376  united states   NQ OMX Green Economy ex-US TR USD
#
# ...

# %%
usa_indices_df[usa_indices_df['full_name'].str.contains("solar", case=False)]
# Out:
#            country                       name                      full_name  \
# 732  united states               NQ OMX Solar               NASDAQ OMX Solar
# 733  united states  NQ OMX Solar Total Return  NASDAQ OMX Solar Total Return
#
#         symbol currency          class         market
# 732   GRNSOLAR      USD  other_indices  world_indices
# 733  GRNSOLARX      USD  other_indices  world_indices

# %%
usa_indices_df[usa_indices_df['full_name'].str.contains('real estate', case=False)]
# Out:
#             country                                               name  \
# 56    united states        NQ US Mid Cap Real Estate Investment Trusts
# 57    united states    NQ US Mid Cap Real Estate Investment & Services
# 58    united states                          NQ US Mid Cap Real Estate
# 200   united states      NQ US Benchmark Real Estate Investment Trusts
# 201   united states               NQ US Benchmark Real Estate Services
# 280   united states      NQ US Large Cap Real Estate Investment Trusts
# 296   united states                        NQ US Large Cap Real Estate
# 433   united states                                S&P 500 Real Estate
# 487   united states      NQ US Small Cap Real Estate Investment Trusts
# 488   united states               NQ US Small Cap Real Estate Services
# 489   united states  NQ US Small Cap Real Estate Holding & Development
# 490   united states  NQ US Small Cap Real Estate Investment & Services
# ...

# %%
usa_indices_df[usa_indices_df['full_name'].str.contains('Information Technology', case=False)]
# Out:
#            country                                       name  \
# 431  united states             S&P 500 Information Technology
# 715  united states             S&P 400 Information Technology
# 774  united states             S&P 600 Information Technology
# 786  united states  S&P Composite 1500 Information Technology
#
#                                      full_name  symbol currency  \
# 431             S&P 500 Information Technology  SPLRCT      USD
# 715             S&P 400 Information Technology  SPMDCT      USD
# 774             S&P 600 Information Technology  SPSMCT      USD
# 786  S&P Composite 1500 Information Technology  SPCOMT      USD
#
#                class         market
# 431  primary_sectors  world_indices
# 715    other_indices  world_indices
# 774    other_indices  world_indices
# 786    other_indices  world_indices

# %%
investpy.indices.get_indices_dict()
# Out:
# [{'country': 'argentina',
#   'name': 'S&P Merval',
#   'full_name': 'S&P Merval',
#   'symbol': 'MERV',
#   'currency': 'ARS',
#   'class': 'major_indices',
#   'market': 'world_indices'},
#  {'country': 'argentina',
#   'name': 'BNY Mellon Argentina ADR TR',
#   'full_name': 'BNY Mellon Argentina ADR Total Return',
#   'symbol': 'BKART',
#   'currency': 'USD',
#   'class': 'additional_indices',
#   'market': 'global_indices'},
#  {'country': 'argentina',
#   'name': 'BNY Mellon Argentina ADR',
#   'full_name': 'BNY Mellon Argentina ADR',
#   'symbol': 'BKAR',
#   'currency': 'USD',
#   'class': 'additional_indices',
#   'market': 'global_indices'},
#  {'country': 'argentina',
#   'name': 'MAE Fixed Income',
#   'full_name': 'MAE Fixed Income',
#   'symbol': 'MAEFI',
#   'currency': 'ARS',
#   'class': 'other_indices',
#   'market': 'world_indices'},
#  {'country': 'argentina',
#   'name': 'S&P/BYMA Argentina General',
#   'full_name': 'S&P/BYMA Argentina General',
# ...
